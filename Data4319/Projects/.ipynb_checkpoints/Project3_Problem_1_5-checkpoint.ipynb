# %% [markdown]
# # Chapter 1: Problem 1.4 from "Learning from Data, A Short Course"
#
# ![title](prob1_5.jpg)

# %%
using Plots

# %% [markdown]
# #### Code recycled from problem 1.4

# %%
# Linear seperable data function 
function make_linearily_separable_data(n)
    coeff = rand(2)
    X = rand(n,2)
    above = []
    below = []
    
    for i = 1:n
        if coeff[1]*X[i,1] + coeff[2] < X[i,2]
            push!(above, (X[i,1], X[i,2]))
        end
        
        if coeff[1]*X[i,1] + coeff[2] > X[i,2]
            push!(below, (X[i,1], X[i,2]))
        end
    end
    
    return above, below, coeff
end
# Out:
# make_linearily_separable_data (generic function with 1 method)

# %%
# Make random collection of linearily seperable data
above, below, coeff = make_linearily_separable_data(100)
scatter([x for x in above], label="above")
scatter!([x for x in below], label="below")
plot!(x->coeff[1]*x + coeff[2], label = "Target f(x)")

# %%
# Make data arrays 
Y_train = [1 for _ in above]
D_train = [x for x in above]
for x in below
    push!(D_train, x)
    push!(Y_train, -1)
end

# %%
# Assign random weights
w = rand(3)

# Perceptron Hypothesis Function 
function h(w, x)
    x_new = [1.0, x[1], x[2]]
    return w'x_new > 0 ? 1 : -1
end

# Perceptron Learning Algorithm 
function PLA_2!(w, x, y, n)
    n = n
    if h(w, x)*y < 1
        s = h(w,x)
        w += n*(y-s)*[1.0, x[1], x[2]]
    end
    return w
end
# Out:
# PLA_2! (generic function with 1 method)

# %% [markdown]
# #### X will be our input data, Y will be the labels

# %%
X, Y = [[x[1], x[2]] for x in D_train], [x[1] == 1 ? 1 : -1 for x in Y_train]
# Iterate the PLA 
for i = 1:1000
    j = rand(1:100)
    w = PLA_2!(w, X[j], Y[j], 100)
end
w1 = w
# Out:
# 3-element Array{Float64,1}:
#  -599.1636049870623
#    28.294809933517442
#  1441.5975648993265

# %%
# Plot the final hypothesis
plot!(x -> -1*(w[2]/w[3])*x - (w[1]/w[3]), label="final approximation with n = 100")

# %%
above2, below2, coeff2 = make_linearily_separable_data(10000)

# Make data arrays 
Y_test = [1 for _ in above2]
D_test = [x for x in above2]
for x in below2
    push!(D_test, x)
    push!(Y_test, -1)
end

X_test, Y_test = [[x[1], x[2]] for x in D_test], [x[1] == 1 ? 1 : -1 for x in Y_test];

# %%
count = 0
w = rand(3)
for j = 1:10000
    if h(w1, X_test[j]) != Y_test[j]
        count +=1
    end
end
error = count/10000
# Out:
# 0.5415

# %%
# Iterate the PLA 
for i = 1:1000
    j = rand(1:100)
    w = PLA_2!(w, X[j], Y[j], 1)
end
w2 = w
# Out:
# 3-element Array{Float64,1}:
#  -5.837021482023608
#  -0.9434341682369869
#  16.697334246351154

# %%
# Plot the final hypothesis
plot!(x -> -1*(w[2]/w[3])*x - (w[1]/w[3]), label="final approximation with n = 1")

# %%
count = 0
w = rand(3)
for j = 1:10000
    if h(w2, X_test[j]) != Y_test[j]
        count +=1
    end
end
error = count/10000
# Out:
# 0.5685

# %%
# Iterate the PLA 
for i = 1:1000
    j = rand(1:100)
    w = PLA_2!(w, X[j], Y[j], 0.01)
end
w3 = w
# Out:
# 3-element Array{Float64,1}:
#  -0.16098950524328418
#  -0.06492666294617772
#   0.4285027931283933

# %%
# Plot the final hypothesis
plot!(x -> -1*(w[2]/w[3])*x - (w[1]/w[3]), label="final approximation with n = 0.01")

# %%
count = 0
w = rand(3)
for j = 1:10000
    if h(w3, X_test[j]) != Y_test[j]
        count +=1
    end
end
error = count/10000
# Out:
# 0.4963

# %%
# Iterate the PLA 
for i = 1:1000
    j = rand(1:100)
    w3 = PLA_2!(w, X[j], Y[j], 0.0001)
end
w4 = w
# Out:
# 3-element Array{Float64,1}:
#  0.2642986866897621
#  0.01995399337040249
#  0.5755945722458047

# %%
# Plot the final hypothesis
plot!(x -> -1*(w[2]/w[3])*x - (w[1]/w[3]), label="final approximation with n = 0.0001")

# %%
count = 0
w = rand(3)
for j = 1:10000
    if h(w4, X_test[j]) != Y_test[j]
        count +=1
    end
end
error = count/10000
# Out:
# 0.9463

# %% [markdown]
# ### From the graphs above and the corresponding error calculations, we can conclude that n = 1 has the smallest error and is our best model.
